# %% [markdown]
# <a href="https://colab.research.google.com/github/garfield-gray/manim/blob/main/Prectice_Manim.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Instructions

# %%
# !sudo apt update
# !sudo apt install libcairo2-dev ffmpeg \
    texlive texlive-latex-extra texlive-fonts-extra \
    texlive-latex-recommended texlive-science \
    tipa libpango1.0-dev
# !pip install manim
# !pip install IPython --upgrade
# Out:
# Hit:1 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Get:2 http://security.ubuntu.com/ubuntu jammy-security InRelease [110 kB]
# Get:3 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,626 B]
# Hit:4 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:5 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [119 kB]
# Hit:6 https://ppa.launchpadcontent.net/c2d4u.team/c2d4u4.0+/ubuntu jammy InRelease
# Get:7 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [993 kB]
# Get:8 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [109 kB]
# Hit:9 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Get:10 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [1,235 kB]
# Get:11 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [966 kB]
# Hit:12 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# ...

# %%
from manim import *
from manim.opengl import *
import numpy as np
from colour import Color
# Out:
# Manim Community v0.17.3

# %% [markdown]
# #Code

# %%
# %%manim -qh -v WARNING Basic
#
# class Basic(Scene):
#   def construct(self):
#     polys = VGroup(
#         *[RegularPolygon(3, radius = 1, fill_opacity = 0.8) for j in range(6)]
#     ).arrange(RIGHT)
#     self.play(DrawBorderThenFill(polys), run_time=2)
#     self.play(
#         # Rotate(polys[0], PI, rate_func=lambda t: t),
#         # Rotate(polys[1], PI, rate_func=smooth),
#         # Rotate(polys[2], PI, rate_func=lambda t: np.sin(t*np.pi)),
#         Rotate(polys[3], PI, rate_func=there_and_back),
#         # Rotate(polys[4], PI, rate_func=lambda t: np.sin(t*np.pi)),
#         Rotate(polys[5], PI, rate_func=lambda t: t**2),
#         run_time=2
#     )
#     self.wait(2)
# Out:
# <video controls autoplay loop style="max-width: 60%;"  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>

# %%
# %%manim -qh -v WARNING Lagging
#
# class Lagging(Scene):
#   def construct(self):
#     squares = VGroup(
#         *[Square(color = Color(hue=j/12, saturation=1,luminance=0.5),
#         fill_opacity=0.75)for j in range(12)]).arrange_in_grid(3,4)
#     self.play(AnimationGroup(*[FadeIn(s) for s in squares], lag_ratio=0.1, rate_func=lambda t: np.sqrt(t)))
#
#     self.wait(2)
# Out:
# <video controls autoplay loop style="max-width: 60%;"  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>

# %%
keys = AnimationGroup.__annotations__
# values = AnimationGroup.__defaults__
print(keys)
# print(values)
# Out:
# {}

# %%
dir(AnimationGroup)
# Out:
# ['__annotations__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_setup_scene',
#  '_typecheck_input',
#  'begin',
#  'build_animations_with_timings',
#  'clean_up_from_scene',
#  'copy',
#  'create_starting_mobject',
#  'finish',
#  'get_all_families_zipped',
#  'get_all_mobjects',
#  'get_all_mobjects_to_update',
#  'get_rate_func',
#  'get_run_time',
#  'get_sub_alpha',
#  'init_run_time',
#  'interpolate',
#  'interpolate_mobject',
#  'interpolate_submobject',
#  'is_introducer',
#  'is_remover',
#  'set_name',
#  'set_rate_func',
#  'set_run_time',
#  'update_mobjects']

# %%
# .animate problems (only cares about start and finish) and target and restore
# %%manim -qh -v WARNING Animate

class Animate(Scene):
  def construct(self):
    s1, s2 = Square(), Square()
    self.add(s1,s2)
    self.play(s1.animate.rotate(PI), Rotate(s2, PI), run_time=3)

    # s = VGroup(s1, s2).arrange(UP, buff = 0.5)
    s1.save_state()
    s1.generate_target()
    s1.target.set_fill(color=GREEN, opacity=0.9)
    s1.target.shift(2*RIGHT).scale(0.4)
    self.play(MoveToTarget(s1))
    self.play(Rotate(s1, 0.5*PI), run_time=2)
    s2.save_state()
    self.play(Restore(s1), s2.animate.rotate(0.1*PI).shift(3*LEFT))
    self.play(Restore(s2))


    self.wait(2)
# Out:
# <video controls autoplay loop style="max-width: 60%;"  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>

# %%
# UpdateFromAlphaFunc
# %%manim -qh -v WARNING Custom

class Custom(Scene):
  def construct(self):
    def SpiralOut(mobject, t):
      radius = 3*t
      angle = 4*t*PI

      mobject.move_to(radius*(np.cos(angle)*RIGHT + np.sin(angle)*UP))
      mobject.set_color(Color(hue=t, saturation=1, luminance = 0.5))
      mobject.set_opacity(1-0.5*t)

    # d = Dot(color=WHITE)
    d = Square(side_length=0.5)
    self.add(d)
    self.play(UpdateFromAlphaFunc(d, SpiralOut, run_time=10))
# Out:
# <video controls autoplay loop style="max-width: 60%;"  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>

# %%
# Anatomy of Animation

# %%manim -qh -v WARNING MyAnim



class Disperse(Animation):
  def __init__(self, mobject, dot_radius=0.05, dot_number=100, **kwargs):            #override of __init__
    super().__init__(mobject, **kwargs)            # calling the initialization with thaparent

    self.dot_radius = dot_radius
    self.dot_number = dot_number


  def begin(self):
    dots = VGroup(
        *[Dot(radius=self.dot_radius).move_to(self.mobject.point_from_proportion(p))
        for p in np.linspace(0, 1, self.dot_number)]
    )

    for dot in dots:
      dot.initial_position = dot.get_center()
      dot.shift_vector = 2*(dot.get_center()-self.mobject.get_center())

    dots.set_opacity(0)
    self.mobject.add(dots)
    self.dots = dots

    super().begin()

  def clean_up_from_scene(self, scene: "Scene") -> None:
    super().clean_up_from_scene(scene)
    scene.remove(self.dots)



  def interpolate_mobject(self, alpha: float):
    alpha = self.rate_func(alpha)
    if alpha <= 0.5:
      self.mobject.set_opacity(1-2*alpha, family=False)
      self.dots.set_opacity(2*alpha)
    else:
      self.mobject.set_opacity(0)
      self.dots.set_opacity(2*(1-alpha))
      for dot in self.dots:
        dot.move_to(dot.initial_position + 2*(alpha - 0.5)*dot.shift_vector)





class MyAnim(Scene):
  def construct(self):
    # st = Star(color=YELLOW, fill_opacity=1).scale(3)
    st = Square(color=GREEN, fill_opacity=1).scale(3)
    self.add(st)
    self.wait()
    self.play(Disperse(st, dot_number=400, dot_radius=0.02, run_time = 5))
# Out:
# <video controls autoplay loop style="max-width: 60%;"  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>

# %% [markdown]
# #Updater

# %%
# %%manim -qh -v WARNING ValueTrackerExample
#
# class ValueTrackerExample(Scene):
#     def construct(self):
#         number_line = NumberLine()
#         pointer = Vector(DOWN)
#         label = MathTex("x").add_updater(lambda m: m.next_to(pointer, UP))
#
#         tracker = ValueTracker()
#         pointer.add_updater(
#             lambda m: m.next_to(
#                         number_line.n2p(tracker.get_value()),
#                         UP
#                     )
#         )
#         self.add(number_line, pointer,label)
#         tracker += 1.5
#         self.wait(1)
#         tracker -= 4
#         self.wait(0.5)
#         self.play(tracker.animate.set_value(5)),
#         self.wait(0.5)
#         self.play(tracker.animate.set_value(3))
#         self.play(tracker.animate.increment_value(-2))
#         self.wait(0.5)
# Out:
# <video controls autoplay loop style="max-width: 60%;"  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>

# %%
dir(ValueTracker)
# Out:
# ['__class__',
#  '__deepcopy__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_get_animation_time_progression',
#  'add',
#  'add_foreground_mobject',
#  'add_foreground_mobjects',
#  'add_mobjects_from_animations',
#  'add_sound',
#  'add_subcaption',
#  'add_updater',
#  'begin_animations',
#  'bring_to_back',
#  'bring_to_front',
#  'camera',
#  'check_interactive_embed_is_valid',
#  'clear',
#  'compile_animation_data',
#  'compile_animations',
#  'construct',
#  'embed',
#  'get_attrs',
#  'get_mobject_family_members',
#  'get_moving_and_static_mobjects',
#  'get_moving_mobjects',
#  'get_restructured_mobject_list',
# ...

# %%
# %%manim -qh -v WARNING ValueTrackerPlot
#
# class ValueTrackerPlot(Scene):
#   def construct(self):
#     a = ValueTracker(1)
#     ax = Axes(x_range=[-2, 2, 1],y_range=[-8.5, 8.5, 1], x_length=4, y_length=6)
#     parabola = ax.plot(lambda x: x**2, color=RED)
#     parabola.add_updater(
#         lambda mob: mob.become(ax.plot(lambda x: a.get_value()* x**2, color=RED))
#     )
#     a_number = DecimalNumber(
#         a.get_value(),
#         color=RED,
#         num_decimal_places=3,
#         show_ellipsis=True
#     )
#     a_number.add_updater(
#         lambda mob: mob.set_value(a.get_value()).next_to(parabola, RIGHT)
#     )
#     self.add(ax, parabola, a_number)
#     self.play(a.animate.set_value(2))
#     self.play(a.animate.set_value(-2))
#     self.play(a.animate.set_value(1))
# Out:
# <video controls autoplay loop style="max-width: 60%;"  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>

# %%
# VlueTracker
# %%manim -qh -v WARNING ValueTrackerplot

class ValueTrackerplot(Scene):
  def construct(self):
    v = ValueTracker(1)
    p = ValueTracker()
    ax = Axes(x_range=[-2, 2, 1], y_range=[-9, 9, 1], x_length=4, y_length = 6)
    parabola = ax.plot(lambda x:x**3, color=RED)
    parabola.add_updater(
        lambda mob: mob.become(ax.plot(lambda x: v.get_value() * (x-p.get_value())**3, color=RED))
    )
    v_number = DecimalNumber(
        v.get_value(),
        color=RED,
        num_decimal_places=2,
        show_ellipsis=True
    )
    v_number.add_updater(
        lambda mob: mob.set_value(v.get_value()).next_to(ax, RIGHT)
    )
    self.add(ax, parabola, v_number)
    self.wait()
    self.play(v.animate.set_value(2))
    self.wait()
    self.play(v.animate.set_value(-2), run_time=4)
    self.wait()
    self.play(p.animate.set_value(1), run_time=4)
# Out:
# <video controls autoplay loop style="max-width: 60%;"  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>

# %% [markdown]
# #OpenGL

# %%
# %%manim render --help
# Out:
# Usage: manim render [OPTIONS] FILE [SCENE_NAMES]...
#
#   Render SCENE(S) from the input FILE.
#
#   FILE is the file path of the script or a config file.
#
#   SCENES is an optional list of scenes in the file.
#
# Global options:
#   -c, --config_file TEXT         Specify the configuration file to use for
#                                  render settings.
#   --custom_folders               Use the folders defined in the [custom_folders]
#                                  section of the config file to define the output
#                                  folder structure.
#   --disable_caching              Disable the use of the cache (still generates
#                                  cache files).
#   --flush_cache                  Remove cached partial movie files.
#   --tex_template TEXT            Specify a custom TeX template file.
#   -v, --verbosity [DEBUG|INFO|WARNING|ERROR|CRITICAL]
#                                  Verbosity of CLI output. Changes ffmpeg log
# ...

# %%
# %%manim -qh --renderer=opengl --write_to_movie OpenGLIntro
#
#
# class OpenGLIntro(Scene):
#     def construct(self):
#       hello_world = Tex("Hello World ;)").scale(3)
#       self.play(Write(hello_world))
#       self.play(
#           self.camera.animate.set_euler_angles(
#               theta=-10*DEGREES,
#               phi=40*DEGREES
#           )
#       )
#       self.play(FadeOut(hello_world))
#       surface = OpenGLSurface(
#           lambda u, v: (u, v, u*np.sin(v) + v*np.cos(u)),
#           u_range=(-3, 3),
#           v_range=(-3, 3)
#       )
#       surface_mesh = OpenGLSurfaceMesh(surface)
#       self.play(Create(surface_mesh))
# Out:
# [09/16/23 19:52:20] INFO     Animation 0 : Using cached data (hash : 2465576764_1901644084_223132457) ]8;id=520746;file:///usr/local/lib/python3.10/dist-packages/manim/utils/caching.py\caching.py]8;;\:]8;id=645778;file:///usr/local/lib/python3.10/dist-packages/manim/utils/caching.py#52\52]8;;\
# INFO:manim:Animation 0 : Using cached data (hash : 2465576764_1901644084_223132457)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 1
# ...

# %%
# %%manim -v WARNING -qm --renderer=opengl --write_to_movie ElectroWaveT
#
# class ElectroWaveT(ThreeDScene):
#   def construct(self):
#     axes = ThreeDAxes()
#     circle=Circle()
#     ax = NumberPlane((0,20),(-3,3),background_line_style={"stroke_opacity": 0})
#     ay = NumberPlane((0,20),(-3,3),background_line_style={"stroke_opacity": 0})
#     ay.rotate(PI/2, axis = RIGHT)
#     time = ValueTracker(0)
#     function = lambda x: -2*np.sin(((2*PI)/5)*time.get_value()-((2*PI)/8)*x)
#     sin = always_redraw(lambda: ax.plot(function, color=RED))
#     sin1 = always_redraw(lambda: ay.plot(function, color=BLUE))
#     d = VGroup()
#     for i in np.arange(0,20.5,0.5):
#       #titik = Circle(radius=0.15).add_updater(lambda y, i=i: y.move_to(ax.c2p(i,-2*np.sin(((2*PI)/5)*time.get_value()-((2*PI)/8)*i))))
#       l1=Arrow(ax.c2p(i,0),ax.c2p(i,-2*np.sin(((2*PI)/5)*time.get_value()-((2*PI)/8)*i)),buff = 0).set_color(RED).set_stroke(width=10)
#       l1.add_updater(lambda z, i=i: z.become(Arrow(ax.c2p(i,0),ax.c2p(i,-2*np.sin(((2*PI)/5)*time.get_value()-((2*PI)/8)*i)),buff = 0).set_color(RED).set_stroke(width=10)))
#       d.add(l1)
#
#     g = VGroup()
#     for i in np.arange(0,20.5,0.5):
#       l2=Arrow(ay.c2p(i,0),ay.c2p(i,-2*np.sin(((2*PI)/5)*time.get_value()-((2*PI)/8)*i)),buff = 0).set_color(BLUE).set_stroke(width=10)
#       l2.add_updater(lambda z, i=i: z.become(Arrow(ay.c2p(i,0),ay.c2p(i,-2*np.sin(((2*PI)/5)*time.get_value()-((2*PI)/8)*i)),buff = 0).set_color(BLUE).set_stroke(width=10)))
#       g.add(l2)
#
#     group = VGroup(d,ax,sin)
#     group1 = VGroup(g,ay,sin1)
#     #text3d.rotate(PI/2)
#     self.set_camera_orientation(phi=70 * DEGREES, theta=30 * DEGREES)
#     self.add(axes,group,group1)
#     self.play(time.animate(run_time=7,rate_func=linear).set_value(20))
#     #self.begin_ambient_camera_rotation(rate=0.8)
#     #self.wait(2)
#     #self.stop_ambient_camera_rotation()
# Out:
# <video controls autoplay loop style="max-width: 60%;"  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>

# %%
# https://colab.research.google.com/drive/1zyuS5lCRDNDiH0jvR0vXHaVztykD_AM4?usp=sharing#scrollTo=J6RNO86teDJ2
